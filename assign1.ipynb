# %%
import pandas as pd

import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv('/home/user/stack/Traffic_Violations.csv')
df['Date Of Stop']=pd.to_datetime(df['Date Of Stop'])
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0   2013-09-24     17:11:00    MCP
# 1   2012-12-20     00:41:00    MCP
# 2   2012-07-20     23:12:00    MCP
# 3   2012-03-19     16:10:00    MCP
# 4   2014-12-01     12:52:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2                         5th district, Germantown
# 3                           2nd district, Bethesda
# 4  6th district, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1                  DRIVING WHILE IMPAIRED BY ALCOHOL
# 2                       FAILURE TO STOP AT STOP SIGN
# 3  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 4                 FAILURE STOP AND YIELD AT THRU HWY
#
#                                  Location   Latitude  Longitude Accident  \
# ...

# %%
df['Stop_Year'] = df['Date Of Stop'].dt.year

# %%
#df.drop('Date Of Stop',axis=1).head()

df =
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0   2013-09-24     17:11:00    MCP
# 1   2012-12-20     00:41:00    MCP
# 2   2012-07-20     23:12:00    MCP
# 3   2012-03-19     16:10:00    MCP
# 4   2014-12-01     12:52:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2                         5th district, Germantown
# 3                           2nd district, Bethesda
# 4  6th district, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1                  DRIVING WHILE IMPAIRED BY ALCOHOL
# 2                       FAILURE TO STOP AT STOP SIGN
# 3  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 4                 FAILURE STOP AND YIELD AT THRU HWY
#
#                                  Location   Latitude  Longitude Accident  \
# ...

# %%
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 2   2012-07-20     23:12:00    MCP
# 3   2012-03-19     16:10:00    MCP
# 4   2014-12-01     12:52:00    MCP
# 5   2012-06-09     21:19:00    MCP
# 6   2012-09-11     21:47:00    MCP
#
#                                          SubAgency  \
# 2                         5th district, Germantown
# 3                           2nd district, Bethesda
# 4  6th district, Gaithersburg / Montgomery Village
# 5                      3rd district, Silver Spring
# 6                            4th district, Wheaton
#
#                                          Description  \
# 2                       FAILURE TO STOP AT STOP SIGN
# 3  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 4                 FAILURE STOP AND YIELD AT THRU HWY
# 5       OCCUPANT UNDER 16 NOT RESTRAINED BY SEATBELT
# 6  PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...
#
#                                  Location   Latitude  Longitude Accident  \
# ...

# %%
locdf = pd.crosstab(df.Stop_Year,df.Location)

# %%
locdf = locdf[locdf.columns[:10]]

# %%
locdf
# Out:
# Empty DataFrame
# Columns: [#2 BRIGHTON DAM RD, #2 DEER PARK LANE, #3 EAST DIAMOND AVE, & STANFORD ST, ( CLOPPER RD 7-11) 12861, (8736) PINEY BRANCH @ BARRON ST, (NORTH)NEW HAMPSHIRE AVE/ CHALMERS, (RT355) @ HENDERSON CORNER ROAD, 011 RIDGE RD, 02 UNIVERSITY BLVD W / 7-11 PARKING LOT]
# Index: []

# %%
#ts=pd.to_datetime(df['Date Of Stop'])
value_count.plot(kind='bar')
plt.title(year)
plt.xlabel('location',size=15)
plt.ylabel('Nuvalue_countmber of Violation', size=15)
plt.show()
